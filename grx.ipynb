# %%
import numpy as np
import pandas as pd
import os
import re
import glob

# %%
# @@ Cell 133
new_cols = [
'gr_first_name',
'gr_last_name',
'test_record_num',
'pt_record_num',
'date_time_of_test',
'distance',
'ambulation_time',
'velocity',
'step_count',
'cadence',
'step_time_sec_left',
'step_length_cm_left',
'step_time_sec_right',
'step_length_cm_right',
'step_extremity_ratio_left',
'step_extremity_ratio_right',
'cycle_time_sec_left',
'cycle_time_sec_right',
'stride_length_cm_left',
'stride_length_cm_right',
'hh_base_support_cm_left',
'hh_base_support_cm_right',
'swing_pct_of_cycle_left',
'swing_pct_of_cycle_right',
'swing_time_sec_left',
'swing_time_sec_right',
'stance_pct_of_cycle_left',
'stance_pct_of_cycle_right',
'stance_time_sec_left',
'stance_time_sec_right',
'sgl_supp_pct_cycle_lt',
'sgl_supp_pct_cycle_rt',
'sgl_supp_time_sec_lt',
'sgl_supp_time_sec_rt',
'dbl_supp_pct_cycle_lt',
'dbl_supp_pct_cycle_rt',
'dbl_supp_time_sec_lt',
'dbl_supp_time_sec_rt',
'step_time_differential',
'step_length_differetial',
'cycle_time_differential',
'functional_amb_profile',
'treatment_count',
'footfalls',
'comments',
'normalized_velocity',
'leg_length_cm_left',
'leg_length_cm_right',
'number_of_passes',
'ambulatory_devices',
'ambulatory_aids',
'user',
'toe_in_out_left',
'toe_in_out_right',
'heel_off_on_time_left',
'heel_off_on_time_right',
'heel_off_on_perc_left',
'heel_off_on_perc_right',
'dbl_supp_load_time_lt',
'dbl_supp_load_time_rt',
'dbl_supp_load_pct_gc_lt',
'dbl_supp_load_pct_gc_rt',
'dbl_supp_unload_time_lt',
'dbl_supp_unload_time_rt',
'dbl_supp_unload_pct_gc_lt',
'dbl_supp_unload_pct_gc_rt',
'asst_ortho_etc_1',
'asst_ortho_etc_2',
'asst_ortho_etc_3',
'asst_ortho_etc_4',
'asst_ortho_etc_5',
'type_of_test',
'software_version',
'number_of_pads',
'normal_group_code',
'standard_walk_steps',
'standard_amb_time',
'stride_velocity_left',
'stride_velocity_right',
'shoe_flag',
'expected_foot_length',
'expected_foot_width',
'foot_length_left',
'foot_width_left',
'foot_length_right',
'foot_width_right',
'step_len_std_dev_lt',
'step_len_std_dev_rt',
'step_time_std_dev_lt',
'step_time_std_dev_rt',
'str_len_std_dev_left',
'str_len_std_dev_rt',
'str_time_std_dev_lt',
'str_time_std_dev_rt',
'swing_time_std_dev_left',
'swing_time_std_dev_right',
'stance_time_std_dev_left',
'stance_time_std_dev_right',
'stride_vel_std_dev_lt',
'stride_vel_std_dev_rt',
'sgl_supp_time_std_dev_lt',
'sgl_supp_time_std_dev_rt',
'dbl_supp_time_std_dev_lt',
'dbl_supp_time_std_dev_rt',
'heel_off_on_std_dev_left',
'heel_off_on_std_dev_right',
'supp_base_std_dev_left',
'supp_base_std_dev_right',
'foot_length_std_dev_left',
'foot_length_std_dev_right',
'foot_width_std_dev_left',
'foot_width_std_dev_right',
'computer_time_msec',
'trigger_1_0',
'trigger_1_1',
'trigger_2_0',
'trigger_2_1',
'trigger_1_e',
'trigger_1_e_1',
'trigger_2_e',
'trigger_2_e_1',
'inclinometer1',
'inclin_avg_tilt_lr',
'inclin_avg_tilt_fb',
'inclin_min_tilt_lr',
'inclin_max_tilt_lr',
'inclin_max_tilt_fb',
'inclin_min_tilt_fb',
'inclin_veloc_tilt_lr',
'inclin_veloc_tilt_fb',
'inclin_sd_tilt_lr',
'inclin_sd_tilt_fb',
'inclinometer2',
'inclin2_avg_tilt_lr',
'inclin2_avg_tilt_fb',
'inclin2_min_tilt_lr',
'inclin2_max_tilt_lr'
]
old_cols = [
'First Name  ',
'Last Name',
'Test Record #',
'Pt Record #',
'Date / Time of Test',
'Distance',
'Ambulation Time',
'Velocity',
'Step Count',
'Cadence',
'Step Time(sec) L',
'Step Length(cm) L',
'Step Time(sec) R',
'Step Length(cm) R',
'Step Extremity(ratio) L',
'Step Extremity(ratio) R',
'Cycle Time(sec) L',
'Cycle Time(sec) R',
'Stride Length(cm) L',
'Stride Length(cm) R',
'HH Base Support (cm) L',
'HH Base Support (cm) R',
'Swing % of Cycle L',
'Swing % of Cycle R',
'Swing Time(sec) L',
'Swing Time(sec) R',
'Stance % of Cycle L',
'Stance % of Cycle R',
'Stance Time(sec)  L',
'Stance Time(sec)  R',
'Single Supp % Cycle L',
'Single Supp % Cycle R',
'Single Supp. Time(sec) L',
'Single Supp. Time(sec) R',
'Double Supp % Cycle L',
'Double Supp % Cycle R',
'Double Supp. Time(sec) L',
'Double Supp. Time(sec) R',
'Step Time Differential',
'Step Length Differential',
'Cycle Time Differential',
'Functional Amb. Profile',
'Treatment Count',
'Footfalls',
'Comments',
'Normalized Velocity  ',
'Leg Length (cm) L',
'Leg Length (cm) R',
'Number of Passes',
'Ambulatory Devices',
'Ambulatory Aids',
'User',
'Toe In / Out L',
'Toe In / Out R',
'Heel Off On Time L',
'Heel Off On Time R',
'Heel Off On Perc L',
'Heel Off On Perc R',
'Double Support Load Time L',
'Double Support Load Time R',
'Double Support Load %GC L',
'Double Support Load %GC R',
'Double Support Unload Time L',
'Double Support Unload Time R',
'Double Support Unload %GC L',
'Double Support Unload %GC R',
'Asst Ortho etc 1',
'Asst Ortho etc  2',
'Asst Ortho etc 3',
'Asst Ortho etc 4',
'Asst Ortho etc 5',
'Type of Test',
'Software Version',
'Number of Pads',
'Normal Group Code',
'Standard Walk Steps',
'Standard Amb Time',
'Stride Velocity Left',
'Stride Velocity Right',
'Shoe Flag',
'Expected Foot Length',
'Expected Foot Width',
'Foot Length Left',
'Foot Width Left',
'Foot Length Right',
'Foot Width Right',
'Step Len Std Dev Left',
'Step Len Std Dev Right',
'Step Time Std Dev Left',
'Step Time Std Dev Right',
'Stride Length Std Dev Left',
'Stride Length Std Dev Right',
'Stride Time Std Dev Left',
'Stride Time Std Dev Right',
'Swing Time Std Dev Left',
'Swing Time Std Dev Right!',
'Stance Time Std Dev Left',
'Stance Time Std Dev Right',
'Stride Velocity Std Dev Left',
'Stride Velocity Std Dev Right',
'Single Supp Time Std Dev Left',
'Single Supp Time Std Dev Right',
'Double Supp Time Std Dev Left',
'Double Supp Time Std Dev Right',
'Heel Off On Std Dev Left',
'Heel Off On Std Dev Right',
'Supp Base Std Dev Left',
'Supp Base Std Dev Right',
'Foot Length Std Dev Left',
'Foot Length Std Dev Right',
'Foot Width Std Dev Left',
'Foot Width Std Dev Right',
'Computer Time (MSec)',
'Trigger 1 0',
'Trigger 1 1',
'Trigger 2 0',
'Trigger 2 1',
'Trigger 1 E',
'Trigger 1 E 1',
'Trigger 2 E',
'Trigger 2 E 1',
'Inclinometer1',
'Inclin_Avg_Tilt_LR',
'Inclin_Avg_Tilt_FB',
'Inclin_Min_Tilt_LR',
'Inclin_Max_Tilt_LR',
'Inclin_Max_Tilt_FB',
'Inclin_Min_Tilt_FB',
'Inclin_Veloc_Tilt_LR',
'Inclin_Veloc_Tilt_FB',
'Inclin_SD_Tilt_LR',
'Inclin_SD_Tilt_FB',
'Inclinometer2',
'Inclin2_Avg_Tilt_LR',
'Inclin2_Avg_Tilt_FB',
'Inclin2_Min_Tilt_LR',
'Inclin2_Max_Tilt_LR'
]

# %%
def grGetTestRecords(filename, event_name, instrument, old_columns, new_columns, lookup_filename, fxs=None):
    if filename.lower().endswith("csv"):
        df = pd.read_csv(filename, dtype=str) 
    elif filename.lower().endswith("xlsx"):
        df = pd.read_excel(filename, dtype=str)
    else:
        raise RuntimeError("Cannot load gaitrite export file - unknown filetype: " + filename)
        
    if fxs==None:
        print("No fxs provided, check filename...")
        # expect file basename to look like NNNNNN-NNN*
        m=re.match(r"(\d{6}-\d{3}).*", os.path.basename(filename))
        if m == None:
            raise RuntimeError("Leading chars of filename must be in FXS format e.g. NNNNNN-NNNwhatever.csv")
        else:
            fxs = m.group(1)
    
    # use fxs to lookup study_id
    if lookup_filename.lower().endswith("csv"):
        lkdf = pd.read_csv(lookup_filename, dtype=str) 
    elif filename.lower().endswith("xlsx"):
        lkdf = pd.read_excel(lookup_filename, dtype=str)
    else:
        raise RuntimeError("Cannot load fxs/id file - unknown filetype: " + lookup_filename)
    lkupdict = dict(zip(lkdf.iloc[:,0], lkdf.iloc[:,1]))
    if fxs in lkupdict:
        studyid = lkupdict[fxs]
    else:
        raise RuntimeError("FXS not found in lookup table: " + fxs)

    # now rename columns
    column_dict = dict(zip(old_columns, new_columns))
    df2 = df[old_columns]
    df3 = df2.rename(columns=column_dict)
    df4 = df3[~df3['test_record_num'].isna()].copy()
        
    # don't forget to add key columns
    # TODO: HARD CODED KEY COLUMN NAME study_id
    # DJS NO, USE "dem_trax_subj_id", taken from filename or maybe command line
    # DJS NO AGAIN, use study_id and dem_trax_subj_id
    df4.insert(0, "study_id", studyid)
    df4.insert(1, "dem_trax_subj_id", fxs)
    
    
    # and don't forget to add the 'redcap_repeat_instance' column and its friend 'redcap_event_name'
    # We use 'new' for the redcap_repeat_instance. The event name has to come with the folder name 
    # as input. 
    df4.insert(2, "redcap_event_name", event_name)
    df4.insert(3, "redcap_repeat_instrument", instrument)
    df4.insert(4, "redcap_repeat_instance", "new")
    
    # and insert the filename
    df4.insert(5, 'input_filename', os.path.basename(filename))
    
    # Assign testtype based on contents of 'comments'
    df4.insert(6, 'testtype', 5)
    df4.loc[df4.comments.str.contains("control", na=False), 'testtype'] = 1
    df4.loc[df4.comments.str.contains("light", na=False), 'testtype'] = 2
    df4.loc[df4.comments.str.contains("loaded", na=False), 'testtype'] = 3
    
    return df4

# %%
# @@ Cell 149
#linux tests = grGetTestRecords('/home/dan/work/rivera-data/500011-138_11_26_19.xlsx', "visit_1_arm_2", "aagrtest", old_cols, new_cols)
#tests = grGetTestRecords('/Users/dan/rivera/tmp/500009-009_08_01_19.xlsx', "visit_1_arm_2", "aagrtest", old_cols, new_cols)
tests = grGetTestRecords('/Users/dan/rivera/tmp/500009-009_03_10_20.xlsx', "visit_2_arm_2", "aagrtest", old_cols, new_cols, '/Users/dan/rivera/FX_ID_TRAX_ID_List.xlsx')
# Out:
# No fxs provided, check filename...

# %%
tests.head()
# Out:
#    study_id dem_trax_subj_id redcap_event_name redcap_repeat_instrument  \
# 0       361       500009-009     visit_2_arm_2                 aagrtest
# 38      361       500009-009     visit_2_arm_2                 aagrtest
# 76      361       500009-009     visit_2_arm_2                 aagrtest
#
#    redcap_repeat_instance            input_filename  testtype gr_first_name  \
# 0                     new  500009-009_03_10_20.xlsx         1    500009-009
# 38                    new  500009-009_03_10_20.xlsx         2           NaN
# 76                    new  500009-009_03_10_20.xlsx         3           NaN
#
#    gr_last_name test_record_num  ... inclin_min_tilt_fb inclin_veloc_tilt_lr  \
# 0           361               3  ...                  0                    0
# 38          NaN               2  ...                  0                    0
# 76          NaN               1  ...                  0                    0
#
#    inclin_veloc_tilt_fb inclin_sd_tilt_lr inclin_sd_tilt_fb inclinometer2  \
# 0                     0                 0                 0             0
# 38                    0                 0                 0             0
# 76                    0                 0                 0             0
#
#    inclin2_avg_tilt_lr inclin2_avg_tilt_fb inclin2_min_tilt_lr  \
# 0                    0                   0                   0
# 38                   0                   0                   0
# 76                   0                   0                   0
#
#    inclin2_max_tilt_lr
# 0                    0
# 38                   0
# 76                   0
#
# [3 rows x 144 columns]

# %%
# @@ Cell 148
tests.to_csv('/Users/dan/rivera/test-should-fail.csv', index=False)

# %%
def readGrExport(filename):
    if filename.lower().endswith("csv"):
        df = pd.read_csv(filename, dtype=str) 
    elif filename.lower().endswith("xlsx"):
        df = pd.read_excel(filename, dtype=str)
    else:
        raise RuntimeError("Cannot load gaitrite export file - unknown filetype: " + filename)
    return df

# %%
def grGetTestRecords2(file_or_dir, event_name, instrument, old_columns, new_columns, lookup_filename, fxs_override=None):
    
    # decide if file_or_dir is a folder or not. 
    # Create a list of filenames (even if its just a filename), then process files in list. 
    file_list = []
    if os.path.isfile(file_or_dir):
        file_list = ([file_or_dir])
    elif os.path.isdir(file_or_dir):
        # get all files in dir
        if fxs_override != None:
            raise RuntimeException("Cannot provide fxsID when using a directory.")
        for f in os.scandir(file_or_dir):
            if (f.is_file() and (f.name.endswith("xlsx") or f.name.endswith("csv"))):
                file_list.append(os.path.join(file_or_dir, f.name))

    # dict for mapping FXS ID to TRAX ID
    dfLookup = readGrExport(lookup_filename)
    dictLookup = dict(zip(dfLookup.iloc[:,0], dfLookup.iloc[:,1])) 

    # dict for renaming columns
    column_dict = dict(zip(old_columns, new_columns))

    # Now get records for each file in list 
    bigdf = None
    for f in file_list:
        print("\nInput file %s" % f)
        df = readGrExport(f)
        fxs = None
        if fxs_override==None:
            # expect file basename to look like NNNNNN-NNN*
            m=re.match(r"(\d{6}-\d{3}).*", os.path.basename(f))
            if m == None:
                raise RuntimeError("Leading chars of filename must be in FXS format e.g. NNNNNN-NNNwhatever.csv")
            else:
                fxs = m.group(1)
                print("FXS from filename: %s" % fxs)

        else:
            fxs = fxs_override
                
        if fxs in dictLookup:
            studyid = dictLookup[fxs]
            print("FXS/TRAX ID: %s/%s" % (fxs, studyid))
        else:
            print("FXS not found in lookup table, skipping file: %s" % fxs)
            #raise RuntimeError("FXS not found in lookup table: " + fxs)
            continue

        df2 = df[old_columns]
        df3 = df2.rename(columns=column_dict)
        df4 = df3[~df3['test_record_num'].isna()].copy()

        # don't forget to add key columns
        # TODO: HARD CODED KEY COLUMN NAME study_id
        # DJS NO, USE "dem_trax_subj_id", taken from filename or maybe command line
        # DJS NO AGAIN, use study_id and dem_trax_subj_id
        df4.insert(0, "study_id", studyid)
        df4.insert(1, "dem_trax_subj_id", fxs)


        # and don't forget to add the 'redcap_repeat_instance' column and its friend 'redcap_event_name'
        # We use 'new' for the redcap_repeat_instance. The event name has to come with the folder name 
        # as input. 
        df4.insert(2, "redcap_event_name", event_name)
        df4.insert(3, "redcap_repeat_instrument", instrument)
        df4.insert(4, "redcap_repeat_instance", "new")

        # and insert the filename
        df4.insert(5, 'input_filename', os.path.basename(f))

        # Assign testtype based on contents of 'comments'
        df4.insert(6, 'testtype', 5)
        df4.loc[df4.comments.str.contains("control", na=False), 'testtype'] = 1
        df4.loc[df4.comments.str.contains("light", na=False), 'testtype'] = 2
        df4.loc[df4.comments.str.contains("loaded", na=False), 'testtype'] = 3
          
        if bigdf is None:
            bigdf = df4
        else:
            bigdf = pd.concat((bigdf, df4))
    
    return bigdf

# %%
#tests = grGetTestRecords2('/Users/dan/rivera/tmp/500009-009_03_10_20.xlsx', "visit_2_arm_2", "aagrtest", old_cols, new_cols, '/Users/dan/rivera/FX_ID_TRAX_ID_List.xlsx')
tests = grGetTestRecords2('/Users/dan/rivera/test', "visit_2_arm_2", "aagrtest", old_cols, new_cols, '/Users/dan/rivera/FX_ID_TRAX_ID_List.xlsx')
# Out:
# Input file /Users/dan/rivera/test/100399-100_12_03_19.xlsx
# FXS from filename: 100399-100
# FXS not found in lookup table, skipping file: 100399-100
#
# Input file /Users/dan/rivera/test/108093-100_09_26_19.xlsx
# FXS from filename: 108093-100
# FXS/TRAX ID: 108093-100/316
#
# Input file /Users/dan/rivera/test/108092-100_09_26_19.xlsx
# FXS from filename: 108092-100
# FXS/TRAX ID: 108092-100/315
#
# Input file /Users/dan/rivera/test/100398-100_05_23_19.xlsx
# FXS from filename: 100398-100
# FXS not found in lookup table, skipping file: 100398-100
#
# Input file /Users/dan/rivera/test/500005-961_03_13_20.xlsx
# FXS from filename: 500005-961
# FXS/TRAX ID: 500005-961/374
#
# Input file /Users/dan/rivera/test/500007-095_04_18_19.xlsx
# FXS from filename: 500007-095
# FXS/TRAX ID: 500007-095/364
#
# Input file /Users/dan/rivera/test/100482-100_01_22_19.xlsx
# FXS from filename: 100482-100
# FXS not found in lookup table, skipping file: 100482-100
#
# Input file /Users/dan/rivera/test/104256-100_05_09_19.xlsx
# FXS from filename: 104256-100
# FXS/TRAX ID: 104256-100/328
#
# Input file /Users/dan/rivera/test/100429-700_10_29_19.xlsx
# FXS from filename: 100429-700
# FXS not found in lookup table, skipping file: 100429-700
#
# Input file /Users/dan/rivera/test/500007-098_10_24_19.xlsx
# FXS from filename: 500007-098
# FXS/TRAX ID: 500007-098/381

# %%
tests
# Out:
#    study_id dem_trax_subj_id redcap_event_name redcap_repeat_instrument  \
# 0       316       108093-100     visit_2_arm_2                 aagrtest
# 34      316       108093-100     visit_2_arm_2                 aagrtest
# 70      316       108093-100     visit_2_arm_2                 aagrtest
# 0       315       108092-100     visit_2_arm_2                 aagrtest
# 32      315       108092-100     visit_2_arm_2                 aagrtest
# 70      315       108092-100     visit_2_arm_2                 aagrtest
# 0       374       500005-961     visit_2_arm_2                 aagrtest
# 41      374       500005-961     visit_2_arm_2                 aagrtest
# 83      374       500005-961     visit_2_arm_2                 aagrtest
# 0       364       500007-095     visit_2_arm_2                 aagrtest
# 36      364       500007-095     visit_2_arm_2                 aagrtest
# 71      364       500007-095     visit_2_arm_2                 aagrtest
# 0       328       104256-100     visit_2_arm_2                 aagrtest
# 36      328       104256-100     visit_2_arm_2                 aagrtest
# 72      328       104256-100     visit_2_arm_2                 aagrtest
# 0       381       500007-098     visit_2_arm_2                 aagrtest
# 34      381       500007-098     visit_2_arm_2                 aagrtest
# 68      381       500007-098     visit_2_arm_2                 aagrtest
#
#    redcap_repeat_instance            input_filename  testtype gr_first_name  \
# 0                     new  108093-100_09_26_19.xlsx         1    108093-100
# 34                    new  108093-100_09_26_19.xlsx         2           NaN
# 70                    new  108093-100_09_26_19.xlsx         3           NaN
# 0                     new  108092-100_09_26_19.xlsx         1    108092-100
# 32                    new  108092-100_09_26_19.xlsx         2           NaN
# 70                    new  108092-100_09_26_19.xlsx         3           NaN
# 0                     new  500005-961_03_13_20.xlsx         3    500005-961
# 41                    new  500005-961_03_13_20.xlsx         2           NaN
# 83                    new  500005-961_03_13_20.xlsx         1           NaN
# 0                     new  500007-095_04_18_19.xlsx         3    500007-095
# 36                    new  500007-095_04_18_19.xlsx         2           NaN
# 71                    new  500007-095_04_18_19.xlsx         1           NaN
# 0                     new  104256-100_05_09_19.xlsx         3    104256-100
# 36                    new  104256-100_05_09_19.xlsx         2           NaN
# 72                    new  104256-100_05_09_19.xlsx         1           NaN
# 0                     new  500007-098_10_24_19.xlsx         1    500007-098
# 34                    new  500007-098_10_24_19.xlsx         2           NaN
# 68                    new  500007-098_10_24_19.xlsx         3           NaN
#
#    gr_last_name test_record_num  ... inclin_min_tilt_fb inclin_veloc_tilt_lr  \
# 0           316               3  ...                  0                    0
# 34          NaN               2  ...                  0                    0
# 70          NaN               1  ...                  0                    0
# 0           315               3  ...                  0                    0
# 32          NaN               2  ...                  0                    0
# 70          NaN               1  ...                  0                    0
# 0           374               3  ...                  0                    0
# 41          NaN               2  ...                  0                    0
# 83          NaN               1  ...                  0                    0
# 0           364               3  ...                  0                    0
# 36          NaN               2  ...                  0                    0
# 71          NaN               1  ...                  0                    0
# 0           328               3  ...                  0                    0
# 36          NaN               2  ...                  0                    0
# 72          NaN               1  ...                  0                    0
# 0           381               3  ...                  0                    0
# 34          NaN               2  ...                  0                    0
# 68          NaN               1  ...                  0                    0
#
#    inclin_veloc_tilt_fb inclin_sd_tilt_lr inclin_sd_tilt_fb inclinometer2  \
# 0                     0                 0                 0             0
# 34                    0                 0                 0             0
# 70                    0                 0                 0             0
# 0                     0                 0                 0             0
# 32                    0                 0                 0             0
# 70                    0                 0                 0             0
# 0                     0                 0                 0             0
# 41                    0                 0                 0             0
# 83                    0                 0                 0             0
# 0                     0                 0                 0             0
# 36                    0                 0                 0             0
# 71                    0                 0                 0             0
# 0                     0                 0                 0             0
# 36                    0                 0                 0             0
# 72                    0                 0                 0             0
# 0                     0                 0                 0             0
# 34                    0                 0                 0             0
# 68                    0                 0                 0             0
#
#    inclin2_avg_tilt_lr inclin2_avg_tilt_fb inclin2_min_tilt_lr  \
# 0                    0                   0                   0
# 34                   0                   0                   0
# 70                   0                   0                   0
# 0                    0                   0                   0
# 32                   0                   0                   0
# 70                   0                   0                   0
# 0                    0                   0                   0
# 41                   0                   0                   0
# 83                   0                   0                   0
# 0                    0                   0                   0
# 36                   0                   0                   0
# 71                   0                   0                   0
# 0                    0                   0                   0
# 36                   0                   0                   0
# 72                   0                   0                   0
# 0                    0                   0                   0
# 34                   0                   0                   0
# 68                   0                   0                   0
#
#    inclin2_max_tilt_lr
# 0                    0
# 34                   0
# 70                   0
# 0                    0
# 32                   0
# 70                   0
# 0                    0
# 41                   0
# 83                   0
# 0                    0
# 36                   0
# 71                   0
# 0                    0
# 36                   0
# 72                   0
# 0                    0
# 34                   0
# 68                   0
#
# [18 rows x 144 columns]

# %%
tests.to_csv('/Users/dan/rivera/test-10.csv', index=False)

# %%
os.listdir('/Users/dan/rivera/test')
# Out:
# ['a.csv',
#  '100399-100_12_03_19.xlsx',
#  'b.csv',
#  '108093-100_09_26_19.xlsx',
#  '108092-100_09_26_19.xlsx',
#  '100398-100_05_23_19.xlsx',
#  '500005-961_03_13_20.xlsx',
#  '500007-095_04_18_19.xlsx',
#  '100482-100_01_22_19.xlsx',
#  '104256-100_05_09_19.xlsx',
#  '100429-700_10_29_19.xlsx',
#  '500007-098_10_24_19.xlsx']
